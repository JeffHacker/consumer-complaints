# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
complaints = pd.read_csv("complaints_dec_2014.csv")
complaints.columns
# Out:
# Index(['Complaint ID', 'Product', 'Sub-product', 'Issue', 'Sub-issue', 'State', 'ZIP code', 'Submitted via', 'Date received', 'Date sent to company', 'Company', 'Company response', 'Timely response?', 'Consumer disputed?'], dtype='object')

# %%
# Number of complaints by product
pd.pivot_table(complaints, index='Complaint ID', columns='Product')
# Out:
#                             ZIP code                            \
# Product      Bank account or service Consumer loan Credit card
# Complaint ID
# 1136157                          NaN           NaN         NaN
# 1136158                          NaN           NaN         NaN
# 1136162                          NaN           NaN         NaN
# 1136169                          NaN           NaN         NaN
# 1136170                          NaN           NaN         NaN
# 1136172                          NaN           NaN         NaN
# 1136173                          NaN           NaN         NaN
# 1136175                          NaN           NaN         NaN
# 1136180                          NaN           NaN         NaN
# 1136183                          NaN           NaN         NaN
# 1136185                          NaN         78577         NaN
# 1136188                          NaN           NaN       11233
# 1136190                          NaN           NaN       30730
# ...

# %%
# Number of complaints by company (top 10 companies only)

# %% [markdown]
# ####These 3 are about the same.  Not hard, I just am not figuring out how to do it from the vids and searches I've taken in today/tonight.

# %%
# Number of complaints by company response

# %%
####Still working out the day part.

# %%
# Mean number of complaints by day of week
# pd.pivot_table(complaints, index='Product', columns='Date received', aggfunc='mean')

# %%
# Any other insights I find interesting

# %%
# Joel live coding
complaints
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-13-4866bb3ae2f3> in <module>()
#       1 # Joel live coding
# ----> 2 complaints.day
#
# /Users/jeffreyhacker/Documents/Python/Iron_Yard/homework/.direnv/python-3.4.3/lib/python3.4/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    1976                 return self[name]
#    1977             raise AttributeError("'%s' object has no attribute '%s'" %
# -> 1978                                  (type(self).__name__, name))
#    1979
#    1980     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'day'
